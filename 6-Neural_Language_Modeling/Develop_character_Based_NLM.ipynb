# %% [markdown]
# ## Neural Language Modeling

# %% [markdown]
# ### Develop a Character-Based Neural Language Model

# %% [markdown]
# ##### Data Preparation

# %%
from os import listdir

# load doc into memory
def load_doc(filename):
    # open the file as read only
    file = open(filename, 'r')
    # read all text
    text = file.read()
    # close the file
    file.close()
    return text

# save tokens to file, one dialog per line
def save_doc(lines, filename):
    data = '\n'.join(lines)
    file = open(filename, 'w')
    file.write(data)
    file.close()

def process_docs(directory):
    documents = list()
    # walk through all files in the folder
    for filename in listdir(directory):
        path = directory + '/' + filename
        # load the doc
        doc = load_doc(path)
        # clean
        tokens = doc.split()
        raw_text = ' '.join(tokens)
        # add to list
        documents.append(raw_text)
    return documents

# load text
raw_text = process_docs(r"D:\NLP\Deep_Learning_in_NLP\phishing_detection\poem")
print(len(raw_text))
# organize into sequences of characters
length = 10
sequences = list()
for i in range(len(raw_text)):
    for j in range(length, len(raw_text[i])):
        # select sequence of tokens
        seq = raw_text[i][j-length:j+1]
        # store
        sequences.append(seq)
print('Total Sequences: %d' % len(sequences))
# save sequences to file
out_filename = 'char_sequences.txt'
save_doc(sequences, out_filename)
# Out:
# 100
# Total Sequences: 236725

# %% [markdown]
# #####  Train Language Model

# %%
from numpy import array
from pickle import dump
from keras.utils import to_categorical
from keras.utils import plot_model
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM

# load doc into memory
def load_doc(filename):
    # open the file as read only
    file = open(filename, 'r')
    # read all text
    text = file.read()
    # close the file
    file.close()
    return text

# define the model
def define_model(X):
    model = Sequential()
    model.add(LSTM(75, input_shape=(X.shape[1], X.shape[2])))
    model.add(Dense(vocab_size, activation='softmax'))
    # compile model
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    # summarize defined model
    model.summary()
    plot_model(model, to_file='model.png', show_shapes=True)
    return model

# load
in_filename = 'char_sequences.txt'
raw_text = load_doc(in_filename)
lines = raw_text.split('\n')
# integer encode sequences of characters
chars = sorted(list(set(raw_text)))
mapping = dict((c, i) for i, c in enumerate(chars))
sequences = list()
for line in lines:
    # integer encode line
    encoded_seq = [mapping[char] for char in line]
    # store
    sequences.append(encoded_seq)
# vocabulary size
vocab_size = len(mapping)
print('Vocabulary Size: %d' % vocab_size)
# separate into input and output
sequences = array(sequences)
X, y = sequences[:,:-1], sequences[:,-1]
sequences = [to_categorical(x, num_classes=vocab_size) for x in X]
X = array(sequences)
y = to_categorical(y, num_classes=vocab_size)
# define model
model = define_model(X)
# fit model
model.fit(X, y, epochs=100, verbose=2)
# save the model to file
model.save('model.h5')
# save the mapping
dump(mapping, open('mapping.pkl', 'wb'))
# Out:
# Vocabulary Size: 95
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 75)                51300
#
#  dense (Dense)               (None, 95)                7220
#
# =================================================================
# Total params: 58520 (228.59 KB)
# Trainable params: 58520 (228.59 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.
# Epoch 1/100
# 7398/7398 - 36s - loss: 2.4191 - accuracy: 0.3293 - 36s/epoch - 5ms/step
# Epoch 2/100
# 7398/7398 - 35s - loss: 2.0973 - accuracy: 0.3981 - 35s/epoch - 5ms/step
# Epoch 3/100
# 7398/7398 - 35s - loss: 1.9842 - accuracy: 0.4271 - 35s/epoch - 5ms/step
# Epoch 4/100
# 7398/7398 - 34s - loss: 1.9132 - accuracy: 0.4446 - 34s/epoch - 5ms/step
# Epoch 5/100
# 7398/7398 - 34s - loss: 1.8611 - accuracy: 0.4573 - 34s/epoch - 5ms/step
# Epoch 6/100
# 7398/7398 - 34s - loss: 1.8211 - accuracy: 0.4680 - 34s/epoch - 5ms/step
# Epoch 7/100
# 7398/7398 - 34s - loss: 1.7881 - accuracy: 0.4772 - 34s/epoch - 5ms/step
# Epoch 8/100
# 7398/7398 - 34s - loss: 1.7614 - accuracy: 0.4841 - 34s/epoch - 5ms/step
# Epoch 9/100
# 7398/7398 - 34s - loss: 1.7385 - accuracy: 0.4896 - 34s/epoch - 5ms/step
# Epoch 10/100
# 7398/7398 - 35s - loss: 1.7188 - accuracy: 0.4945 - 35s/epoch - 5ms/step
# Epoch 11/100
# 7398/7398 - 36s - loss: 1.7017 - accuracy: 0.4994 - 36s/epoch - 5ms/step
# Epoch 12/100
# 7398/7398 - 36s - loss: 1.6861 - accuracy: 0.5034 - 36s/epoch - 5ms/step
# Epoch 13/100
# 7398/7398 - 34s - loss: 1.6731 - accuracy: 0.5071 - 34s/epoch - 5ms/step
# Epoch 14/100
# 7398/7398 - 34s - loss: 1.6603 - accuracy: 0.5100 - 34s/epoch - 5ms/step
# Epoch 15/100
# 7398/7398 - 34s - loss: 1.6498 - accuracy: 0.5129 - 34s/epoch - 5ms/step
# Epoch 16/100
# 7398/7398 - 34s - loss: 1.6392 - accuracy: 0.5155 - 34s/epoch - 5ms/step
# Epoch 17/100
# 7398/7398 - 34s - loss: 1.6295 - accuracy: 0.5190 - 34s/epoch - 5ms/step
# Epoch 18/100
# 7398/7398 - 35s - loss: 1.6203 - accuracy: 0.5209 - 35s/epoch - 5ms/step
# Epoch 19/100
# 7398/7398 - 34s - loss: 1.6123 - accuracy: 0.5229 - 34s/epoch - 5ms/step
# Epoch 20/100
# 7398/7398 - 34s - loss: 1.6046 - accuracy: 0.5247 - 34s/epoch - 5ms/step
# Epoch 21/100
# 7398/7398 - 34s - loss: 1.5978 - accuracy: 0.5272 - 34s/epoch - 5ms/step
# Epoch 22/100
# 7398/7398 - 34s - loss: 1.5906 - accuracy: 0.5291 - 34s/epoch - 5ms/step
# Epoch 23/100
# 7398/7398 - 34s - loss: 1.5844 - accuracy: 0.5304 - 34s/epoch - 5ms/step
# Epoch 24/100
# 7398/7398 - 34s - loss: 1.5788 - accuracy: 0.5325 - 34s/epoch - 5ms/step
# Epoch 25/100
# 7398/7398 - 34s - loss: 1.5729 - accuracy: 0.5332 - 34s/epoch - 5ms/step
# Epoch 26/100
# 7398/7398 - 35s - loss: 1.5676 - accuracy: 0.5351 - 35s/epoch - 5ms/step
# Epoch 27/100
# 7398/7398 - 34s - loss: 1.5623 - accuracy: 0.5362 - 34s/epoch - 5ms/step
# Epoch 28/100
# 7398/7398 - 34s - loss: 1.5574 - accuracy: 0.5387 - 34s/epoch - 5ms/step
# Epoch 29/100
# 7398/7398 - 34s - loss: 1.5534 - accuracy: 0.5388 - 34s/epoch - 5ms/step
# Epoch 30/100
# 7398/7398 - 34s - loss: 1.5486 - accuracy: 0.5392 - 34s/epoch - 5ms/step
# Epoch 31/100
# 7398/7398 - 34s - loss: 1.5441 - accuracy: 0.5410 - 34s/epoch - 5ms/step
# Epoch 32/100
# 7398/7398 - 35s - loss: 1.5407 - accuracy: 0.5420 - 35s/epoch - 5ms/step
# Epoch 33/100
# 7398/7398 - 40s - loss: 1.5363 - accuracy: 0.5433 - 40s/epoch - 5ms/step
# Epoch 34/100
# 7398/7398 - 39s - loss: 1.5329 - accuracy: 0.5438 - 39s/epoch - 5ms/step
# Epoch 35/100
# 7398/7398 - 37s - loss: 1.5296 - accuracy: 0.5450 - 37s/epoch - 5ms/step
# Epoch 36/100
# 7398/7398 - 35s - loss: 1.5255 - accuracy: 0.5459 - 35s/epoch - 5ms/step
# Epoch 37/100
# 7398/7398 - 35s - loss: 1.5226 - accuracy: 0.5479 - 35s/epoch - 5ms/step
# Epoch 38/100
# 7398/7398 - 35s - loss: 1.5191 - accuracy: 0.5479 - 35s/epoch - 5ms/step
# Epoch 39/100
# 7398/7398 - 35s - loss: 1.5169 - accuracy: 0.5489 - 35s/epoch - 5ms/step
# Epoch 40/100
# 7398/7398 - 35s - loss: 1.5134 - accuracy: 0.5496 - 35s/epoch - 5ms/step
# Epoch 41/100
# 7398/7398 - 35s - loss: 1.5107 - accuracy: 0.5500 - 35s/epoch - 5ms/step
# Epoch 42/100
# 7398/7398 - 35s - loss: 1.5083 - accuracy: 0.5514 - 35s/epoch - 5ms/step
# Epoch 43/100
# 7398/7398 - 35s - loss: 1.5052 - accuracy: 0.5520 - 35s/epoch - 5ms/step
# Epoch 44/100
# 7398/7398 - 35s - loss: 1.5029 - accuracy: 0.5525 - 35s/epoch - 5ms/step
# Epoch 45/100
# 7398/7398 - 35s - loss: 1.5004 - accuracy: 0.5532 - 35s/epoch - 5ms/step
# Epoch 46/100
# 7398/7398 - 35s - loss: 1.4979 - accuracy: 0.5538 - 35s/epoch - 5ms/step
# Epoch 47/100
# 7398/7398 - 35s - loss: 1.4959 - accuracy: 0.5542 - 35s/epoch - 5ms/step
# Epoch 48/100
# 7398/7398 - 35s - loss: 1.4939 - accuracy: 0.5548 - 35s/epoch - 5ms/step
# Epoch 49/100
# 7398/7398 - 35s - loss: 1.4913 - accuracy: 0.5559 - 35s/epoch - 5ms/step
# Epoch 50/100
# 7398/7398 - 35s - loss: 1.4899 - accuracy: 0.5561 - 35s/epoch - 5ms/step
# Epoch 51/100
# 7398/7398 - 35s - loss: 1.4876 - accuracy: 0.5568 - 35s/epoch - 5ms/step
# Epoch 52/100
# 7398/7398 - 35s - loss: 1.4852 - accuracy: 0.5573 - 35s/epoch - 5ms/step
# Epoch 53/100
# 7398/7398 - 35s - loss: 1.4838 - accuracy: 0.5578 - 35s/epoch - 5ms/step
# Epoch 54/100
# 7398/7398 - 35s - loss: 1.4824 - accuracy: 0.5576 - 35s/epoch - 5ms/step
# Epoch 55/100
# 7398/7398 - 35s - loss: 1.4804 - accuracy: 0.5591 - 35s/epoch - 5ms/step
# Epoch 56/100
# 7398/7398 - 33s - loss: 1.4786 - accuracy: 0.5590 - 33s/epoch - 4ms/step
# Epoch 57/100
# 7398/7398 - 23s - loss: 1.4766 - accuracy: 0.5598 - 23s/epoch - 3ms/step
# Epoch 58/100
# 7398/7398 - 23s - loss: 1.4755 - accuracy: 0.5598 - 23s/epoch - 3ms/step
# Epoch 59/100
# 7398/7398 - 23s - loss: 1.4739 - accuracy: 0.5605 - 23s/epoch - 3ms/step
# Epoch 60/100
# 7398/7398 - 24s - loss: 1.4726 - accuracy: 0.5605 - 24s/epoch - 3ms/step
# Epoch 61/100
# 7398/7398 - 23s - loss: 1.4706 - accuracy: 0.5614 - 23s/epoch - 3ms/step
# Epoch 62/100
# 7398/7398 - 23s - loss: 1.4698 - accuracy: 0.5613 - 23s/epoch - 3ms/step
# Epoch 63/100
# 7398/7398 - 23s - loss: 1.4677 - accuracy: 0.5614 - 23s/epoch - 3ms/step
# Epoch 64/100
# 7398/7398 - 23s - loss: 1.4670 - accuracy: 0.5621 - 23s/epoch - 3ms/step
# Epoch 65/100
# 7398/7398 - 23s - loss: 1.4651 - accuracy: 0.5622 - 23s/epoch - 3ms/step
# Epoch 66/100
# 7398/7398 - 23s - loss: 1.4636 - accuracy: 0.5631 - 23s/epoch - 3ms/step
# Epoch 67/100
# 7398/7398 - 24s - loss: 1.4622 - accuracy: 0.5635 - 24s/epoch - 3ms/step
# Epoch 68/100
# 7398/7398 - 23s - loss: 1.4607 - accuracy: 0.5638 - 23s/epoch - 3ms/step
# Epoch 69/100
# 7398/7398 - 23s - loss: 1.4598 - accuracy: 0.5639 - 23s/epoch - 3ms/step
# Epoch 70/100
# 7398/7398 - 24s - loss: 1.4589 - accuracy: 0.5642 - 24s/epoch - 3ms/step
# Epoch 71/100
# 7398/7398 - 24s - loss: 1.4576 - accuracy: 0.5644 - 24s/epoch - 3ms/step
# Epoch 72/100
# 7398/7398 - 36s - loss: 1.4566 - accuracy: 0.5645 - 36s/epoch - 5ms/step
# Epoch 73/100
# 7398/7398 - 35s - loss: 1.4553 - accuracy: 0.5647 - 35s/epoch - 5ms/step
# Epoch 74/100
# 7398/7398 - 35s - loss: 1.4544 - accuracy: 0.5653 - 35s/epoch - 5ms/step
# Epoch 75/100
# 7398/7398 - 36s - loss: 1.4538 - accuracy: 0.5653 - 36s/epoch - 5ms/step
# Epoch 76/100
# 7398/7398 - 35s - loss: 1.4526 - accuracy: 0.5656 - 35s/epoch - 5ms/step
# Epoch 77/100
# 7398/7398 - 34s - loss: 1.4515 - accuracy: 0.5661 - 34s/epoch - 5ms/step
# Epoch 78/100
# 7398/7398 - 34s - loss: 1.4504 - accuracy: 0.5668 - 34s/epoch - 5ms/step
# Epoch 79/100
# 7398/7398 - 34s - loss: 1.4497 - accuracy: 0.5667 - 34s/epoch - 5ms/step
# Epoch 80/100
# 7398/7398 - 34s - loss: 1.4485 - accuracy: 0.5670 - 34s/epoch - 5ms/step
# Epoch 81/100
# 7398/7398 - 34s - loss: 1.4478 - accuracy: 0.5667 - 34s/epoch - 5ms/step
# Epoch 82/100
# 7398/7398 - 34s - loss: 1.4470 - accuracy: 0.5674 - 34s/epoch - 5ms/step
# Epoch 83/100
# 7398/7398 - 35s - loss: 1.4461 - accuracy: 0.5671 - 35s/epoch - 5ms/step
# Epoch 84/100
# 7398/7398 - 35s - loss: 1.4452 - accuracy: 0.5681 - 35s/epoch - 5ms/step
# Epoch 85/100
# 7398/7398 - 35s - loss: 1.4442 - accuracy: 0.5684 - 35s/epoch - 5ms/step
# Epoch 86/100
# 7398/7398 - 36s - loss: 1.4441 - accuracy: 0.5687 - 36s/epoch - 5ms/step
# Epoch 87/100
# 7398/7398 - 33s - loss: 1.4428 - accuracy: 0.5685 - 33s/epoch - 4ms/step
# Epoch 88/100
# 7398/7398 - 23s - loss: 1.4425 - accuracy: 0.5691 - 23s/epoch - 3ms/step
# Epoch 89/100
# 7398/7398 - 24s - loss: 1.4414 - accuracy: 0.5692 - 24s/epoch - 3ms/step
# Epoch 90/100
# 7398/7398 - 23s - loss: 1.4409 - accuracy: 0.5684 - 23s/epoch - 3ms/step
# Epoch 91/100
# 7398/7398 - 23s - loss: 1.4396 - accuracy: 0.5696 - 23s/epoch - 3ms/step
# Epoch 92/100
# 7398/7398 - 23s - loss: 1.4391 - accuracy: 0.5692 - 23s/epoch - 3ms/step
# Epoch 93/100
# 7398/7398 - 23s - loss: 1.4394 - accuracy: 0.5696 - 23s/epoch - 3ms/step
# Epoch 94/100
# 7398/7398 - 24s - loss: 1.4384 - accuracy: 0.5701 - 24s/epoch - 3ms/step
# Epoch 95/100
# 7398/7398 - 24s - loss: 1.4377 - accuracy: 0.5704 - 24s/epoch - 3ms/step
# Epoch 96/100
# 7398/7398 - 23s - loss: 1.4369 - accuracy: 0.5700 - 23s/epoch - 3ms/step
# Epoch 97/100
# 7398/7398 - 23s - loss: 1.4364 - accuracy: 0.5701 - 23s/epoch - 3ms/step
# Epoch 98/100
# 7398/7398 - 23s - loss: 1.4365 - accuracy: 0.5706 - 23s/epoch - 3ms/step
# Epoch 99/100
# 7398/7398 - 23s - loss: 1.4350 - accuracy: 0.5712 - 23s/epoch - 3ms/step
# Epoch 100/100
# 7398/7398 - 23s - loss: 1.4352 - accuracy: 0.5706 - 23s/epoch - 3ms/step
# c:\Users\Faegheh\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# ##### Generate Text

# %%
from pickle import load
import numpy as np
from keras.models import load_model
from keras.utils import to_categorical
from keras.preprocessing.sequence import pad_sequences

# generate a sequence of characters with a language model
def generate_seq(model, mapping, seq_length, seed_text, n_chars):
    in_text = seed_text
    # generate a fixed number of characters
    for _ in range(n_chars):
        # encode the characters as integers
        encoded = [mapping[char] for char in in_text]
        # truncate sequences to a fixed length
        encoded = pad_sequences([encoded], maxlen=seq_length, truncating='pre')
        # one hot encode
        encoded = to_categorical(encoded, num_classes=len(mapping))
        #reshaped_data = encoded.reshape(1, encoded.shape[0], encoded.shape[1])
        # predict character
        #yhat_probabilities = model.predict(reshaped_data, verbose=0)
        #yhat = np.argmax(yhat_probabilities)
        yhat = model.predict(encoded, verbose=0)
        predicted_index = np.argmax(yhat)
        # reverse map integer to character
        out_char = ''
        for char, index in mapping.items():
            if index == predicted_index:
                out_char = char
                break
        # append to input
        in_text += out_char
    return in_text
# load the model
model = load_model('model.h5')
# load the mapping
mapping = load(open('mapping.pkl', 'rb'))
# test start of rhyme
print(generate_seq(model, mapping, 10, 'will be ve', 20))
# test mid-line
print(generate_seq(model, mapping, 10, 'he strive ', 20))
# test not in original
print(generate_seq(model, mapping, 10, 'hello wor', 20))
# Out:
# will be venneming the rest of
# he strive of a hands the strik
# hello words, and which the sa
