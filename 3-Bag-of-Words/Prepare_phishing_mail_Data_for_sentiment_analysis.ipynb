# %% [markdown]
# ## Bag-of-Words
#
# ### Prepare email body for Sentiment Analysis

# %%
# load doc into memory
def load_doc(filename):
    # open the file as read only
    file = open(filename, 'r')
    # read all text
    text = file.read()
    # close the file
    file.close()
    return text

# %% [markdown]
# #### Load Text Data

# %%
from os import listdir
# load doc into memory
def load_doc(filename):
    # open the file as read only
    file = open(filename, 'r',  encoding="utf-8")
    # read all text
    text = file.read()
    # close the file
    file.close()
    return text
# load all docs in a directory
def process_docs(directory):
# walk through all files in the folder
    for filename in listdir(directory):
        # skip files that do not have the right extension
        if not filename.endswith(".txt"):
            next
    # create the full path of the file to open
        path = directory + '/' + filename
        # load document
        doc = load_doc(path)
        print('Loaded %s' % filename)
# specify directory to load
directory = r"D:\NLP\Deep_Learning_in_NLP\phishing_detection\Clean"
process_docs(directory)
# Out:
# Loaded record_1.txt
# Loaded record_1001.txt
# Loaded record_1004.txt
# Loaded record_1005.txt
# Loaded record_1006.txt
# Loaded record_101.txt
# Loaded record_1012.txt
# Loaded record_1013.txt
# Loaded record_1014.txt
# Loaded record_1020.txt
# Loaded record_1021.txt
# Loaded record_1022.txt
# Loaded record_1027.txt
# Loaded record_1030.txt
# Loaded record_1032.txt
# Loaded record_1033.txt
# Loaded record_1037.txt
# Loaded record_1038.txt
# Loaded record_1039.txt
# Loaded record_1041.txt
# Loaded record_1042.txt
# Loaded record_1045.txt
# Loaded record_1046.txt
# Loaded record_1050.txt
# Loaded record_1055.txt
# Loaded record_1058.txt
# Loaded record_1059.txt
# Loaded record_106.txt
# Loaded record_1064.txt
# Loaded record_1068.txt
# Loaded record_1069.txt
# Loaded record_1072.txt
# Loaded record_1075.txt
# Loaded record_1076.txt
# Loaded record_1078.txt
# Loaded record_1079.txt
# Loaded record_108.txt
# Loaded record_1083.txt
# Loaded record_1084.txt
# Loaded record_1093.txt
# Loaded record_1095.txt
# Loaded record_1096.txt
# Loaded record_11.txt
# Loaded record_110.txt
# Loaded record_1100.txt
# Loaded record_1101.txt
# Loaded record_1107.txt
# Loaded record_1110.txt
# Loaded record_1111.txt
# Loaded record_1112.txt
# Loaded record_1113.txt
# Loaded record_1121.txt
# Loaded record_1125.txt
# Loaded record_1127.txt
# Loaded record_1129.txt
# Loaded record_113.txt
# Loaded record_1133.txt
# Loaded record_1134.txt
# Loaded record_1136.txt
# Loaded record_1141.txt
# Loaded record_1142.txt
# Loaded record_1144.txt
# Loaded record_1156.txt
# Loaded record_1157.txt
# Loaded record_1162.txt
# Loaded record_1163.txt
# Loaded record_1164.txt
# Loaded record_1165.txt
# Loaded record_1167.txt
# Loaded record_1168.txt
# Loaded record_1170.txt
# Loaded record_1174.txt
# Loaded record_1175.txt
# Loaded record_1176.txt
# Loaded record_1177.txt
# Loaded record_1179.txt
# Loaded record_1180.txt
# Loaded record_1183.txt
# Loaded record_1184.txt
# Loaded record_1185.txt
# Loaded record_1186.txt
# Loaded record_1187.txt
# Loaded record_1189.txt
# Loaded record_119.txt
# Loaded record_1192.txt
# Loaded record_1196.txt
# Loaded record_1199.txt
# Loaded record_1200.txt
# Loaded record_1201.txt
# Loaded record_1202.txt
# Loaded record_1203.txt
# Loaded record_1207.txt
# Loaded record_121.txt
# Loaded record_1211.txt
# Loaded record_1212.txt
# Loaded record_1215.txt
# Loaded record_1217.txt
# Loaded record_1218.txt
# Loaded record_1222.txt
# Loaded record_1226.txt
# Loaded record_1233.txt
# Loaded record_1235.txt
# Loaded record_1236.txt
# Loaded record_124.txt
# Loaded record_1243.txt
# Loaded record_1244.txt
# Loaded record_1245.txt
# Loaded record_1249.txt
# Loaded record_1254.txt
# Loaded record_1255.txt
# Loaded record_1259.txt
# Loaded record_126.txt
# Loaded record_1260.txt
# Loaded record_1262.txt
# Loaded record_1267.txt
# Loaded record_1270.txt
# Loaded record_1271.txt
# Loaded record_1272.txt
# Loaded record_1273.txt
# Loaded record_1278.txt
# Loaded record_1279.txt
# Loaded record_1280.txt
# Loaded record_1283.txt
# Loaded record_1286.txt
# Loaded record_129.txt
# Loaded record_1291.txt
# Loaded record_1292.txt
# Loaded record_1293.txt
# Loaded record_1301.txt
# Loaded record_1313.txt
# Loaded record_1314.txt
# Loaded record_1316.txt
# Loaded record_1324.txt
# Loaded record_1326.txt
# Loaded record_1327.txt
# Loaded record_1334.txt
# Loaded record_1338.txt
# Loaded record_1340.txt
# Loaded record_1341.txt
# Loaded record_1342.txt
# Loaded record_1346.txt
# Loaded record_1348.txt
# Loaded record_1349.txt
# Loaded record_1351.txt
# Loaded record_1353.txt
# Loaded record_1354.txt
# Loaded record_1357.txt
# Loaded record_1361.txt
# Loaded record_1367.txt
# Loaded record_1370.txt
# Loaded record_1372.txt
# Loaded record_1374.txt
# Loaded record_1375.txt
# Loaded record_1383.txt
# Loaded record_1385.txt
# Loaded record_1389.txt
# Loaded record_1393.txt
# Loaded record_1395.txt
# Loaded record_1396.txt
# Loaded record_1398.txt
# Loaded record_1399.txt
# Loaded record_14.txt
# Loaded record_140.txt
# Loaded record_1400.txt
# Loaded record_1407.txt
# Loaded record_1409.txt
# Loaded record_1413.txt
# Loaded record_1419.txt
# Loaded record_1420.txt
# Loaded record_1421.txt
# Loaded record_1422.txt
# Loaded record_1423.txt
# Loaded record_1424.txt
# Loaded record_1425.txt
# Loaded record_1430.txt
# Loaded record_1432.txt
# Loaded record_1438.txt
# Loaded record_144.txt
# Loaded record_1441.txt
# Loaded record_1442.txt
# Loaded record_1443.txt
# Loaded record_1444.txt
# Loaded record_1445.txt
# Loaded record_1448.txt
# Loaded record_145.txt
# Loaded record_1453.txt
# Loaded record_1454.txt
# Loaded record_1455.txt
# Loaded record_1458.txt
# Loaded record_1460.txt
# Loaded record_1461.txt
# Loaded record_1463.txt
# Loaded record_1465.txt
# Loaded record_1466.txt
# Loaded record_1468.txt
# Loaded record_1471.txt
# Loaded record_1472.txt
# Loaded record_1476.txt
# Loaded record_148.txt
# Loaded record_1481.txt
# Loaded record_1488.txt
# Loaded record_1490.txt
# Loaded record_1495.txt
# Loaded record_1496.txt
# Loaded record_1498.txt
# Loaded record_15.txt
# Loaded record_150.txt
# Loaded record_1504.txt
# Loaded record_1506.txt
# Loaded record_1507.txt
# Loaded record_1509.txt
# Loaded record_151.txt
# Loaded record_1511.txt
# Loaded record_1512.txt
# Loaded record_1513.txt
# Loaded record_1515.txt
# Loaded record_1516.txt
# Loaded record_1517.txt
# Loaded record_1527.txt
# Loaded record_1531.txt
# Loaded record_1534.txt
# Loaded record_1535.txt
# Loaded record_154.txt
# Loaded record_1542.txt
# Loaded record_1543.txt
# Loaded record_1544.txt
# Loaded record_1549.txt
# Loaded record_1550.txt
# Loaded record_1552.txt
# Loaded record_1553.txt
# Loaded record_1554.txt
# Loaded record_1556.txt
# Loaded record_1558.txt
# Loaded record_1560.txt
# Loaded record_1561.txt
# Loaded record_1562.txt
# Loaded record_1564.txt
# Loaded record_1570.txt
# Loaded record_1571.txt
# Loaded record_1572.txt
# Loaded record_1574.txt
# Loaded record_1575.txt
# Loaded record_1577.txt
# Loaded record_1581.txt
# Loaded record_1582.txt
# Loaded record_1585.txt
# Loaded record_1586.txt
# Loaded record_1588.txt
# Loaded record_159.txt
# Loaded record_1590.txt
# Loaded record_1591.txt
# Loaded record_1594.txt
# Loaded record_1595.txt
# Loaded record_1597.txt
# Loaded record_1601.txt
# Loaded record_1603.txt
# Loaded record_1607.txt
# Loaded record_161.txt
# Loaded record_1612.txt
# Loaded record_1613.txt
# Loaded record_1614.txt
# Loaded record_1616.txt
# Loaded record_1619.txt
# Loaded record_162.txt
# Loaded record_1622.txt
# Loaded record_1623.txt
# Loaded record_1624.txt
# Loaded record_1625.txt
# Loaded record_1627.txt
# Loaded record_1628.txt
# Loaded record_1632.txt
# Loaded record_1635.txt
# Loaded record_1639.txt
# Loaded record_164.txt
# Loaded record_1644.txt
# Loaded record_1645.txt
# Loaded record_1649.txt
# Loaded record_1650.txt
# Loaded record_1658.txt
# Loaded record_1659.txt
# Loaded record_166.txt
# Loaded record_1662.txt
# Loaded record_1664.txt
# Loaded record_1665.txt
# Loaded record_1669.txt
# Loaded record_1672.txt
# Loaded record_1675.txt
# Loaded record_1676.txt
# Loaded record_1679.txt
# Loaded record_1680.txt
# Loaded record_1684.txt
# Loaded record_1686.txt
# Loaded record_1689.txt
# Loaded record_169.txt
# Loaded record_1694.txt
# Loaded record_1695.txt
# Loaded record_1696.txt
# Loaded record_1699.txt
# Loaded record_17.txt
# Loaded record_170.txt
# Loaded record_1703.txt
# Loaded record_1704.txt
# Loaded record_1708.txt
# Loaded record_1709.txt
# Loaded record_1712.txt
# Loaded record_1715.txt
# Loaded record_1718.txt
# Loaded record_1719.txt
# Loaded record_1720.txt
# Loaded record_1722.txt
# Loaded record_1724.txt
# Loaded record_1728.txt
# Loaded record_173.txt
# Loaded record_1730.txt
# Loaded record_1731.txt
# Loaded record_1733.txt
# Loaded record_1735.txt
# Loaded record_1737.txt
# Loaded record_1738.txt
# Loaded record_1739.txt
# Loaded record_174.txt
# Loaded record_1740.txt
# Loaded record_1742.txt
# Loaded record_1743.txt
# Loaded record_1744.txt
# Loaded record_1746.txt
# Loaded record_1752.txt
# Loaded record_1757.txt
# Loaded record_1758.txt
# Loaded record_176.txt
# Loaded record_1762.txt
# Loaded record_1771.txt
# Loaded record_1772.txt
# Loaded record_1774.txt
# Loaded record_1775.txt
# Loaded record_1776.txt
# Loaded record_1779.txt
# Loaded record_1780.txt
# Loaded record_1781.txt
# Loaded record_1787.txt
# Loaded record_1788.txt
# Loaded record_1789.txt
# Loaded record_1790.txt
# Loaded record_1792.txt
# Loaded record_1795.txt
# Loaded record_1796.txt
# Loaded record_1798.txt
# Loaded record_1801.txt
# Loaded record_1804.txt
# Loaded record_1805.txt
# Loaded record_1809.txt
# Loaded record_181.txt
# Loaded record_1810.txt
# Loaded record_1812.txt
# Loaded record_1813.txt
# Loaded record_1819.txt
# Loaded record_182.txt
# Loaded record_1821.txt
# Loaded record_1822.txt
# Loaded record_1829.txt
# Loaded record_1830.txt
# Loaded record_1835.txt
# Loaded record_1839.txt
# Loaded record_184.txt
# Loaded record_1842.txt
# Loaded record_1848.txt
# Loaded record_185.txt
# Loaded record_1852.txt
# Loaded record_1856.txt
# Loaded record_1857.txt
# Loaded record_1861.txt
# Loaded record_1867.txt
# Loaded record_1868.txt
# Loaded record_1869.txt
# Loaded record_1871.txt
# Loaded record_1877.txt
# Loaded record_1879.txt
# Loaded record_188.txt
# Loaded record_1881.txt
# Loaded record_1884.txt
# Loaded record_1885.txt
# Loaded record_1889.txt
# Loaded record_1892.txt
# Loaded record_1894.txt
# Loaded record_1901.txt
# Loaded record_1902.txt
# Loaded record_1906.txt
# Loaded record_1907.txt
# Loaded record_1913.txt
# Loaded record_1914.txt
# Loaded record_1915.txt
# Loaded record_1916.txt
# Loaded record_1920.txt
# Loaded record_1922.txt
# Loaded record_1928.txt
# Loaded record_193.txt
# Loaded record_1931.txt
# Loaded record_1932.txt
# Loaded record_1933.txt
# Loaded record_1939.txt
# Loaded record_1940.txt
# Loaded record_1942.txt
# Loaded record_1945.txt
# Loaded record_1946.txt
# Loaded record_1950.txt
# Loaded record_1951.txt
# Loaded record_1955.txt
# Loaded record_1959.txt
# Loaded record_196.txt
# Loaded record_1967.txt
# Loaded record_1971.txt
# Loaded record_1973.txt
# Loaded record_1976.txt
# Loaded record_1978.txt
# Loaded record_1979.txt
# Loaded record_1982.txt
# Loaded record_1985.txt
# Loaded record_1986.txt
# Loaded record_1988.txt
# Loaded record_199.txt
# Loaded record_1990.txt
# Loaded record_1991.txt
# Loaded record_1992.txt
# Loaded record_1994.txt
# Loaded record_2.txt
# Loaded record_200.txt
# Loaded record_2000.txt
# Loaded record_2001.txt
# Loaded record_2003.txt
# Loaded record_2004.txt
# Loaded record_2010.txt
# Loaded record_2012.txt
# Loaded record_2018.txt
# Loaded record_202.txt
# Loaded record_2021.txt
# Loaded record_2029.txt
# Loaded record_2033.txt
# Loaded record_2036.txt
# Loaded record_2038.txt
# Loaded record_2039.txt
# Loaded record_204.txt
# Loaded record_2051.txt
# Loaded record_2052.txt
# Loaded record_2054.txt
# Loaded record_2055.txt
# Loaded record_2060.txt
# Loaded record_2061.txt
# Loaded record_2062.txt
# Loaded record_2063.txt
# Loaded record_2064.txt
# Loaded record_2066.txt
# Loaded record_2067.txt
# Loaded record_2068.txt
# Loaded record_2069.txt
# Loaded record_2072.txt
# Loaded record_2074.txt
# Loaded record_208.txt
# Loaded record_2081.txt
# Loaded record_2087.txt
# Loaded record_2088.txt
# Loaded record_2089.txt
# Loaded record_209.txt
# Loaded record_2090.txt
# Loaded record_2097.txt
# Loaded record_210.txt
# Loaded record_2100.txt
# Loaded record_2109.txt
# Loaded record_2114.txt
# Loaded record_2116.txt
# Loaded record_2117.txt
# Loaded record_2118.txt
# Loaded record_2119.txt
# Loaded record_212.txt
# Loaded record_2120.txt
# Loaded record_213.txt
# Loaded record_2132.txt
# Loaded record_2133.txt
# Loaded record_2134.txt
# Loaded record_2135.txt
# Loaded record_2136.txt
# Loaded record_2138.txt
# Loaded record_2139.txt
# Loaded record_2143.txt
# Loaded record_2144.txt
# Loaded record_2145.txt
# Loaded record_2146.txt
# Loaded record_2148.txt
# Loaded record_2152.txt
# Loaded record_2153.txt
# Loaded record_2154.txt
# Loaded record_2155.txt
# Loaded record_2158.txt
# Loaded record_2159.txt
# Loaded record_2165.txt
# Loaded record_2170.txt
# Loaded record_2172.txt
# Loaded record_2178.txt
# Loaded record_218.txt
# Loaded record_2181.txt
# Loaded record_2184.txt
# Loaded record_2186.txt
# Loaded record_2187.txt
# Loaded record_2189.txt
# Loaded record_2191.txt
# Loaded record_2193.txt
# Loaded record_2194.txt
# Loaded record_2195.txt
# Loaded record_220.txt
# Loaded record_2201.txt
# Loaded record_2204.txt
# Loaded record_2209.txt
# Loaded record_2210.txt
# Loaded record_2211.txt
# Loaded record_2212.txt
# Loaded record_2217.txt
# Loaded record_2226.txt
# Loaded record_2228.txt
# Loaded record_2229.txt
# Loaded record_2231.txt
# Loaded record_2233.txt
# Loaded record_2234.txt
# Loaded record_2235.txt
# Loaded record_2236.txt
# Loaded record_2237.txt
# Loaded record_224.txt
# Loaded record_2240.txt
# Loaded record_2241.txt
# Loaded record_2242.txt
# Loaded record_2244.txt
# Loaded record_2245.txt
# Loaded record_2247.txt
# Loaded record_2248.txt
# Loaded record_225.txt
# Loaded record_2251.txt
# Loaded record_2252.txt
# Loaded record_2254.txt
# Loaded record_2255.txt
# Loaded record_2256.txt
# Loaded record_2257.txt
# Loaded record_2259.txt
# Loaded record_2262.txt
# Loaded record_227.txt
# Loaded record_2271.txt
# Loaded record_2275.txt
# Loaded record_2281.txt
# Loaded record_2289.txt
# Loaded record_229.txt
# Loaded record_2292.txt
# Loaded record_2294.txt
# Loaded record_2295.txt
# Loaded record_2299.txt
# Loaded record_23.txt
# Loaded record_230.txt
# Loaded record_2305.txt
# Loaded record_2306.txt
# Loaded record_231.txt
# Loaded record_2311.txt
# Loaded record_2312.txt
# Loaded record_2317.txt
# Loaded record_2318.txt
# Loaded record_2320.txt
# Loaded record_2321.txt
# Loaded record_2323.txt
# Loaded record_2324.txt
# Loaded record_2326.txt
# Loaded record_2329.txt
# Loaded record_233.txt
# Loaded record_2331.txt
# Loaded record_2332.txt
# Loaded record_2333.txt
# Loaded record_2335.txt
# Loaded record_2341.txt
# Loaded record_2344.txt
# Loaded record_2347.txt
# Loaded record_2349.txt
# Loaded record_2352.txt
# Loaded record_2356.txt
# Loaded record_2357.txt
# Loaded record_236.txt
# Loaded record_2362.txt
# Loaded record_2363.txt
# Loaded record_2365.txt
# Loaded record_2368.txt
# Loaded record_2369.txt
# Loaded record_237.txt
# Loaded record_2373.txt
# Loaded record_2374.txt
# Loaded record_2375.txt
# Loaded record_2377.txt
# Loaded record_2378.txt
# Loaded record_238.txt
# Loaded record_2381.txt
# Loaded record_2383.txt
# Loaded record_2384.txt
# Loaded record_2386.txt
# Loaded record_2387.txt
# Loaded record_2388.txt
# Loaded record_2389.txt
# Loaded record_2391.txt
# Loaded record_2392.txt
# Loaded record_2393.txt
# Loaded record_2394.txt
# Loaded record_2398.txt
# Loaded record_2399.txt
# Loaded record_24.txt
# Loaded record_2406.txt
# Loaded record_2410.txt
# Loaded record_2411.txt
# Loaded record_2412.txt
# Loaded record_2413.txt
# Loaded record_2422.txt
# Loaded record_2427.txt
# Loaded record_2428.txt
# Loaded record_243.txt
# Loaded record_2432.txt
# Loaded record_2433.txt
# Loaded record_2436.txt
# Loaded record_2439.txt
# Loaded record_2441.txt
# Loaded record_2442.txt
# Loaded record_2443.txt
# Loaded record_2444.txt
# Loaded record_245.txt
# Loaded record_2455.txt
# Loaded record_2458.txt
# Loaded record_2460.txt
# Loaded record_2465.txt
# Loaded record_2466.txt
# Loaded record_2467.txt
# Loaded record_2469.txt
# Loaded record_247.txt
# Loaded record_2470.txt
# Loaded record_2471.txt
# Loaded record_2472.txt
# Loaded record_2474.txt
# Loaded record_2477.txt
# Loaded record_2479.txt
# Loaded record_248.txt
# Loaded record_2483.txt
# Loaded record_2485.txt
# Loaded record_2486.txt
# Loaded record_2487.txt
# Loaded record_2488.txt
# Loaded record_249.txt
# Loaded record_2492.txt
# Loaded record_2494.txt
# Loaded record_2495.txt
# Loaded record_2496.txt
# Loaded record_2498.txt
# Loaded record_2499.txt
# Loaded record_2501.txt
# Loaded record_2503.txt
# Loaded record_2506.txt
# Loaded record_2507.txt
# Loaded record_2508.txt
# Loaded record_251.txt
# Loaded record_2513.txt
# Loaded record_2519.txt
# Loaded record_252.txt
# Loaded record_2525.txt
# Loaded record_2526.txt
# Loaded record_2529.txt
# Loaded record_2531.txt
# Loaded record_2533.txt
# Loaded record_2534.txt
# Loaded record_2536.txt
# Loaded record_2540.txt
# Loaded record_2542.txt
# Loaded record_2544.txt
# Loaded record_2545.txt
# Loaded record_2547.txt
# Loaded record_2551.txt
# Loaded record_2553.txt
# Loaded record_2554.txt
# Loaded record_2558.txt
# Loaded record_2559.txt
# Loaded record_2561.txt
# Loaded record_2562.txt
# Loaded record_2563.txt
# Loaded record_2565.txt
# Loaded record_2569.txt
# Loaded record_2572.txt
# Loaded record_2576.txt
# Loaded record_2578.txt
# Loaded record_2581.txt
# Loaded record_2584.txt
# Loaded record_2587.txt
# Loaded record_259.txt
# Loaded record_2591.txt
# Loaded record_2596.txt
# Loaded record_26.txt
# Loaded record_2601.txt
# Loaded record_2602.txt
# Loaded record_2603.txt
# Loaded record_2608.txt
# Loaded record_2609.txt
# Loaded record_2611.txt
# Loaded record_2617.txt
# Loaded record_2618.txt
# Loaded record_2623.txt
# Loaded record_2624.txt
# Loaded record_2626.txt
# Loaded record_2627.txt
# Loaded record_2631.txt
# Loaded record_2632.txt
# Loaded record_2633.txt
# Loaded record_2637.txt
# Loaded record_2638.txt
# Loaded record_264.txt
# Loaded record_2644.txt
# Loaded record_2646.txt
# Loaded record_2648.txt
# Loaded record_2649.txt
# Loaded record_2650.txt
# Loaded record_2651.txt
# Loaded record_2652.txt
# Loaded record_2653.txt
# Loaded record_2656.txt
# Loaded record_2662.txt
# Loaded record_2667.txt
# Loaded record_2668.txt
# Loaded record_2670.txt
# Loaded record_2676.txt
# Loaded record_2677.txt
# Loaded record_2681.txt
# Loaded record_2683.txt
# Loaded record_269.txt
# Loaded record_2690.txt
# Loaded record_2691.txt
# Loaded record_2693.txt
# Loaded record_2700.txt
# Loaded record_2701.txt
# Loaded record_2702.txt
# Loaded record_2703.txt
# Loaded record_2705.txt
# Loaded record_2706.txt
# Loaded record_2707.txt
# Loaded record_2708.txt
# Loaded record_271.txt
# Loaded record_2711.txt
# Loaded record_2715.txt
# Loaded record_2716.txt
# Loaded record_2718.txt
# Loaded record_272.txt
# Loaded record_2722.txt
# Loaded record_2724.txt
# Loaded record_2725.txt
# Loaded record_2727.txt
# Loaded record_2728.txt
# Loaded record_2732.txt
# Loaded record_2735.txt
# Loaded record_2738.txt
# Loaded record_2739.txt
# Loaded record_2740.txt
# Loaded record_2744.txt
# Loaded record_2746.txt
# Loaded record_2747.txt
# Loaded record_2749.txt
# Loaded record_2750.txt
# Loaded record_2751.txt
# Loaded record_2754.txt
# Loaded record_2755.txt
# Loaded record_2756.txt
# Loaded record_2759.txt
# Loaded record_2765.txt
# Loaded record_2766.txt
# Loaded record_2767.txt
# Loaded record_2768.txt
# Loaded record_277.txt
# Loaded record_2770.txt
# Loaded record_2774.txt
# Loaded record_2776.txt
# Loaded record_2778.txt
# Loaded record_278.txt
# Loaded record_2780.txt
# Loaded record_2782.txt
# Loaded record_2785.txt
# Loaded record_2789.txt
# Loaded record_279.txt
# Loaded record_2799.txt
# Loaded record_280.txt
# Loaded record_2804.txt
# Loaded record_2812.txt
# Loaded record_2818.txt
# Loaded record_2821.txt
# Loaded record_2822.txt
# Loaded record_2823.txt
# Loaded record_2824.txt
# Loaded record_2825.txt
# Loaded record_2828.txt
# Loaded record_2830.txt
# Loaded record_2831.txt
# Loaded record_2832.txt
# Loaded record_2833.txt
# Loaded record_2834.txt
# Loaded record_2839.txt
# Loaded record_2842.txt
# Loaded record_2843.txt
# Loaded record_2846.txt
# Loaded record_2849.txt
# Loaded record_2850.txt
# Loaded record_2854.txt
# Loaded record_286.txt
# Loaded record_2860.txt
# Loaded record_2861.txt
# Loaded record_2862.txt
# Loaded record_2863.txt
# Loaded record_2866.txt
# Loaded record_2868.txt
# Loaded record_2869.txt
# Loaded record_2875.txt
# Loaded record_2877.txt
# Loaded record_2878.txt
# Loaded record_2880.txt
# Loaded record_2882.txt
# Loaded record_289.txt
# Loaded record_2893.txt
# Loaded record_2895.txt
# Loaded record_29.txt
# Loaded record_290.txt
# Loaded record_2903.txt
# Loaded record_2906.txt
# Loaded record_2907.txt
# Loaded record_2910.txt
# Loaded record_2911.txt
# Loaded record_2912.txt
# Loaded record_2914.txt
# Loaded record_2915.txt
# Loaded record_2921.txt
# Loaded record_2923.txt
# Loaded record_2929.txt
# Loaded record_2930.txt
# Loaded record_2931.txt
# Loaded record_2932.txt
# Loaded record_2933.txt
# Loaded record_2934.txt
# Loaded record_2938.txt
# Loaded record_2939.txt
# Loaded record_294.txt
# Loaded record_2943.txt
# Loaded record_2945.txt
# Loaded record_2947.txt
# Loaded record_2949.txt
# Loaded record_295.txt
# Loaded record_2951.txt
# Loaded record_2952.txt
# Loaded record_2953.txt
# Loaded record_2957.txt
# Loaded record_2958.txt
# Loaded record_296.txt
# Loaded record_2961.txt
# Loaded record_2963.txt
# Loaded record_2964.txt
# Loaded record_2967.txt
# Loaded record_2968.txt
# Loaded record_2969.txt
# Loaded record_2971.txt
# Loaded record_2977.txt
# Loaded record_2979.txt
# Loaded record_2983.txt
# Loaded record_2986.txt
# Loaded record_2989.txt
# Loaded record_2992.txt
# Loaded record_2994.txt
# Loaded record_2998.txt
# Loaded record_2999.txt
# Loaded record_30.txt
# Loaded record_300.txt
# Loaded record_3000.txt
# Loaded record_3003.txt
# Loaded record_3004.txt
# Loaded record_3006.txt
# Loaded record_3007.txt
# Loaded record_3008.txt
# Loaded record_3010.txt
# Loaded record_3012.txt
# Loaded record_3013.txt
# Loaded record_3014.txt
# Loaded record_3015.txt
# Loaded record_3016.txt
# Loaded record_3018.txt
# Loaded record_3020.txt
# Loaded record_3023.txt
# Loaded record_3024.txt
# Loaded record_3025.txt
# Loaded record_3026.txt
# Loaded record_3027.txt
# Loaded record_3028.txt
# Loaded record_3029.txt
# Loaded record_3030.txt
# Loaded record_3031.txt
# Loaded record_3033.txt
# Loaded record_3039.txt
# Loaded record_304.txt
# Loaded record_3043.txt
# Loaded record_3044.txt
# Loaded record_3047.txt
# Loaded record_3051.txt
# Loaded record_3059.txt
# Loaded record_3060.txt
# Loaded record_3061.txt
# Loaded record_3063.txt
# Loaded record_3067.txt
# Loaded record_3068.txt
# Loaded record_3069.txt
# Loaded record_3073.txt
# Loaded record_3074.txt
# Loaded record_3075.txt
# Loaded record_3076.txt
# Loaded record_308.txt
# Loaded record_3080.txt
# Loaded record_3081.txt
# Loaded record_3084.txt
# Loaded record_3085.txt
# Loaded record_3086.txt
# Loaded record_309.txt
# Loaded record_3092.txt
# Loaded record_3093.txt
# Loaded record_3101.txt
# Loaded record_3102.txt
# Loaded record_3103.txt
# Loaded record_3108.txt
# Loaded record_3111.txt
# Loaded record_3112.txt
# Loaded record_3114.txt
# Loaded record_3118.txt
# Loaded record_3119.txt
# Loaded record_3978.txt
# Loaded record_398.txt
# Loaded record_3989.txt
# Loaded record_399.txt
# Loaded record_3992.txt
# Loaded record_3996.txt
# Loaded record_4004.txt
# Loaded record_4006.txt
# Loaded record_4015.txt
# Loaded record_4018.txt
# Loaded record_4019.txt
# Loaded record_4021.txt
# Loaded record_4029.txt
# Loaded record_403.txt
# Loaded record_4033.txt
# Loaded record_4036.txt
# Loaded record_4038.txt
# Loaded record_4046.txt
# Loaded record_4047.txt
# Loaded record_4050.txt
# Loaded record_4054.txt
# Loaded record_4056.txt
# Loaded record_4062.txt
# Loaded record_4064.txt
# Loaded record_4065.txt
# Loaded record_4066.txt
# Loaded record_4068.txt
# Loaded record_4069.txt
# Loaded record_4070.txt
# Loaded record_4072.txt
# Loaded record_4074.txt
# Loaded record_4078.txt
# Loaded record_4079.txt
# Loaded record_4080.txt
# Loaded record_4086.txt
# Loaded record_4088.txt
# Loaded record_4089.txt
# Loaded record_409.txt
# Loaded record_4091.txt
# Loaded record_4092.txt
# Loaded record_4094.txt
# Loaded record_4099.txt
# Loaded record_410.txt
# Loaded record_4102.txt
# Loaded record_4107.txt
# Loaded record_4113.txt
# Loaded record_4115.txt
# Loaded record_4116.txt
# Loaded record_4117.txt
# Loaded record_4118.txt
# Loaded record_412.txt
# Loaded record_4121.txt
# Loaded record_4122.txt
# Loaded record_4126.txt
# Loaded record_4129.txt
# Loaded record_4132.txt
# Loaded record_4134.txt
# Loaded record_4135.txt
# Loaded record_4136.txt
# Loaded record_4138.txt
# Loaded record_4139.txt
# Loaded record_4144.txt
# Loaded record_4145.txt
# Loaded record_4147.txt
# Loaded record_4148.txt
# Loaded record_4149.txt
# Loaded record_4150.txt
# Loaded record_4157.txt
# Loaded record_416.txt
# Loaded record_4161.txt
# Loaded record_4163.txt
# Loaded record_4164.txt
# Loaded record_4165.txt
# Loaded record_4169.txt
# Loaded record_417.txt
# Loaded record_4171.txt
# Loaded record_4174.txt
# Loaded record_4177.txt
# Loaded record_4181.txt
# Loaded record_4183.txt
# Loaded record_4184.txt
# Loaded record_4190.txt
# Loaded record_4191.txt
# Loaded record_4193.txt
# Loaded record_4194.txt
# Loaded record_4198.txt
# Loaded record_420.txt
# Loaded record_4200.txt
# Loaded record_4201.txt
# Loaded record_4202.txt
# Loaded record_4204.txt
# Loaded record_4206.txt
# Loaded record_4207.txt
# Loaded record_421.txt
# Loaded record_4210.txt
# Loaded record_4211.txt
# Loaded record_4212.txt
# Loaded record_4219.txt
# Loaded record_422.txt
# Loaded record_4220.txt
# Loaded record_4221.txt
# Loaded record_4226.txt
# Loaded record_4231.txt
# Loaded record_4235.txt
# Loaded record_4236.txt
# Loaded record_4238.txt
# Loaded record_4244.txt
# Loaded record_4246.txt
# Loaded record_4247.txt
# Loaded record_4248.txt
# Loaded record_4250.txt
# Loaded record_4251.txt
# Loaded record_4256.txt
# Loaded record_426.txt
# Loaded record_4260.txt
# Loaded record_4261.txt
# Loaded record_4265.txt
# Loaded record_4268.txt
# Loaded record_4269.txt
# Loaded record_4270.txt
# Loaded record_4280.txt
# Loaded record_4281.txt
# Loaded record_4282.txt
# Loaded record_4285.txt
# Loaded record_429.txt
# Loaded record_4290.txt
# Loaded record_4292.txt
# Loaded record_4294.txt
# Loaded record_4299.txt
# Loaded record_43.txt
# Loaded record_4301.txt
# Loaded record_4302.txt
# Loaded record_4306.txt
# Loaded record_4307.txt
# Loaded record_4308.txt
# Loaded record_431.txt
# Loaded record_4312.txt
# Loaded record_4314.txt
# Loaded record_4315.txt
# Loaded record_4317.txt
# Loaded record_4319.txt
# Loaded record_4321.txt
# Loaded record_4333.txt
# Loaded record_4334.txt
# Loaded record_4338.txt
# Loaded record_4339.txt
# Loaded record_434.txt
# Loaded record_4347.txt
# Loaded record_4348.txt
# Loaded record_4350.txt
# Loaded record_4351.txt
# Loaded record_4354.txt
# Loaded record_4355.txt
# Loaded record_4357.txt
# Loaded record_4358.txt
# Loaded record_436.txt
# Loaded record_4360.txt
# Loaded record_4365.txt
# Loaded record_4371.txt
# Loaded record_4375.txt
# Loaded record_4376.txt
# Loaded record_4379.txt
# Loaded record_4387.txt
# Loaded record_4395.txt
# Loaded record_4396.txt
# Loaded record_4397.txt
# Loaded record_4398.txt
# Loaded record_44.txt
# Loaded record_4400.txt
# Loaded record_4402.txt
# Loaded record_4404.txt
# Loaded record_4406.txt
# Loaded record_4408.txt
# Loaded record_441.txt
# Loaded record_4410.txt
# Loaded record_4416.txt
# Loaded record_4417.txt
# Loaded record_4420.txt
# Loaded record_4423.txt
# Loaded record_4425.txt
# Loaded record_4427.txt
# Loaded record_4428.txt
# Loaded record_4429.txt
# Loaded record_443.txt
# Loaded record_4430.txt
# Loaded record_4435.txt
# Loaded record_4437.txt
# Loaded record_4442.txt
# Loaded record_4444.txt
# Loaded record_4445.txt
# Loaded record_445.txt
# Loaded record_4450.txt
# Loaded record_4451.txt
# Loaded record_4453.txt
# Loaded record_4454.txt
# Loaded record_4455.txt
# Loaded record_4459.txt
# Loaded record_446.txt
# Loaded record_4463.txt
# Loaded record_4466.txt
# Loaded record_447.txt
# Loaded record_4470.txt
# Loaded record_4473.txt
# Loaded record_4474.txt
# Loaded record_4478.txt
# Loaded record_4480.txt
# Loaded record_4481.txt
# Loaded record_4484.txt
# Loaded record_4488.txt
# Loaded record_4495.txt
# Loaded record_4496.txt
# Loaded record_4497.txt
# Loaded record_4498.txt
# Loaded record_4500.txt
# Loaded record_4501.txt
# Loaded record_4503.txt
# Loaded record_4505.txt
# Loaded record_4509.txt
# Loaded record_4511.txt
# Loaded record_4513.txt
# Loaded record_4515.txt
# Loaded record_4517.txt
# Loaded record_4520.txt
# Loaded record_4526.txt
# Loaded record_4527.txt
# Loaded record_4533.txt
# Loaded record_4535.txt
# Loaded record_4540.txt
# Loaded record_4541.txt
# Loaded record_4544.txt
# Loaded record_4545.txt
# Loaded record_4547.txt
# Loaded record_4548.txt
# Loaded record_4549.txt
# Loaded record_455.txt
# Loaded record_4552.txt
# Loaded record_4553.txt
# Loaded record_4785.txt
# Loaded record_4786.txt
# Loaded record_4788.txt
# Loaded record_4797.txt
# Loaded record_480.txt
# Loaded record_4801.txt
# Loaded record_4804.txt
# Loaded record_4807.txt
# Loaded record_4809.txt
# Loaded record_4812.txt
# Loaded record_4815.txt
# Loaded record_4822.txt
# Loaded record_4825.txt
# Loaded record_4826.txt
# Loaded record_4827.txt
# Loaded record_4830.txt
# Loaded record_4833.txt
# Loaded record_4838.txt
# Loaded record_4840.txt
# Loaded record_4841.txt
# Loaded record_4843.txt
# Loaded record_4844.txt
# Loaded record_4845.txt
# Loaded record_4848.txt
# Loaded record_4849.txt
# Loaded record_485.txt
# Loaded record_4850.txt
# Loaded record_4851.txt
# Loaded record_4852.txt
# Loaded record_4858.txt
# Loaded record_486.txt
# Loaded record_4860.txt
# Loaded record_4863.txt
# Loaded record_487.txt
# Loaded record_4874.txt
# Loaded record_4876.txt
# Loaded record_4878.txt
# Loaded record_4879.txt
# Loaded record_4883.txt
# Loaded record_4885.txt
# Loaded record_4886.txt
# Loaded record_4889.txt
# Loaded record_489.txt
# Loaded record_4890.txt
# Loaded record_4893.txt
# Loaded record_4896.txt
# Loaded record_490.txt
# Loaded record_4904.txt
# Loaded record_4905.txt
# Loaded record_4910.txt
# Loaded record_4911.txt
# Loaded record_4918.txt
# Loaded record_4920.txt
# Loaded record_4925.txt
# Loaded record_4928.txt
# Loaded record_4929.txt
# Loaded record_4931.txt
# Loaded record_4933.txt
# Loaded record_4938.txt
# Loaded record_4939.txt
# Loaded record_4942.txt
# Loaded record_4944.txt
# Loaded record_4945.txt
# Loaded record_4946.txt
# Loaded record_4949.txt
# Loaded record_4951.txt
# Loaded record_4954.txt
# Loaded record_4956.txt
# Loaded record_4958.txt
# Loaded record_4961.txt
# Loaded record_4962.txt
# Loaded record_4964.txt
# Loaded record_4967.txt
# Loaded record_4968.txt
# Loaded record_497.txt
# Loaded record_4972.txt
# Loaded record_4973.txt
# Loaded record_4976.txt
# Loaded record_4979.txt
# Loaded record_498.txt
# Loaded record_4980.txt
# Loaded record_4984.txt
# Loaded record_4995.txt
# Loaded record_4996.txt
# Loaded record_4997.txt
# Loaded record_4998.txt
# Loaded record_4999.txt
# Loaded record_50.txt
# Loaded record_5004.txt
# Loaded record_501.txt
# Loaded record_5012.txt
# Loaded record_5013.txt
# Loaded record_5018.txt
# Loaded record_502.txt
# Loaded record_5020.txt
# Loaded record_5025.txt
# Loaded record_5027.txt
# Loaded record_5028.txt
# Loaded record_5032.txt
# Loaded record_5033.txt
# Loaded record_5035.txt
# Loaded record_5041.txt
# Loaded record_5047.txt
# Loaded record_5048.txt
# Loaded record_5049.txt
# Loaded record_5052.txt
# Loaded record_5053.txt
# Loaded record_5054.txt
# Loaded record_5055.txt
# Loaded record_5058.txt
# Loaded record_5064.txt
# Loaded record_5065.txt
# Loaded record_5067.txt
# Loaded record_5068.txt
# Loaded record_507.txt
# Loaded record_5073.txt
# Loaded record_5074.txt
# Loaded record_5075.txt
# Loaded record_5076.txt
# Loaded record_5077.txt
# Loaded record_5078.txt
# Loaded record_5079.txt
# Loaded record_508.txt
# Loaded record_5083.txt
# Loaded record_5084.txt
# Loaded record_5085.txt
# Loaded record_5086.txt
# Loaded record_5087.txt
# Loaded record_5092.txt
# Loaded record_5093.txt
# Loaded record_5095.txt
# Loaded record_5098.txt
# Loaded record_5100.txt
# Loaded record_5107.txt
# Loaded record_5108.txt
# Loaded record_5110.txt
# Loaded record_5111.txt
# Loaded record_5113.txt
# Loaded record_5115.txt
# Loaded record_5122.txt
# Loaded record_5124.txt
# Loaded record_5130.txt
# Loaded record_5131.txt
# Loaded record_5132.txt
# Loaded record_5134.txt
# Loaded record_5135.txt
# Loaded record_5140.txt
# Loaded record_5142.txt
# Loaded record_5145.txt
# Loaded record_5147.txt
# Loaded record_5148.txt
# Loaded record_5153.txt
# Loaded record_5154.txt
# Loaded record_5158.txt
# Loaded record_5161.txt
# Loaded record_5163.txt
# Loaded record_5168.txt
# Loaded record_517.txt
# Loaded record_5174.txt
# Loaded record_5178.txt
# Loaded record_5179.txt
# Loaded record_518.txt
# Loaded record_5183.txt
# Loaded record_5184.txt
# Loaded record_5185.txt
# Loaded record_5187.txt
# Loaded record_5188.txt
# Loaded record_5189.txt
# Loaded record_519.txt
# Loaded record_5190.txt
# Loaded record_5191.txt
# Loaded record_5192.txt
# Loaded record_5194.txt
# Loaded record_5196.txt
# Loaded record_5197.txt
# Loaded record_5198.txt
# Loaded record_5199.txt
# Loaded record_5200.txt
# Loaded record_5201.txt
# Loaded record_5202.txt
# Loaded record_5204.txt
# Loaded record_5205.txt
# Loaded record_5206.txt
# Loaded record_521.txt
# Loaded record_5213.txt
# Loaded record_5214.txt
# Loaded record_5218.txt
# Loaded record_5219.txt
# Loaded record_5220.txt
# Loaded record_523.txt
# Loaded record_5232.txt
# Loaded record_5233.txt
# Loaded record_5236.txt
# Loaded record_5238.txt
# Loaded record_524.txt
# Loaded record_5242.txt
# Loaded record_5243.txt
# Loaded record_5246.txt
# Loaded record_5247.txt
# Loaded record_525.txt
# Loaded record_5251.txt
# Loaded record_5254.txt
# Loaded record_5262.txt
# Loaded record_5265.txt
# Loaded record_5266.txt
# Loaded record_5269.txt
# Loaded record_527.txt
# Loaded record_5272.txt
# Loaded record_5275.txt
# Loaded record_5278.txt
# Loaded record_528.txt
# Loaded record_5280.txt
# Loaded record_5281.txt
# Loaded record_5282.txt
# Loaded record_5285.txt
# Loaded record_5290.txt
# Loaded record_5293.txt
# Loaded record_5298.txt
# Loaded record_5299.txt
# Loaded record_53.txt
# Loaded record_530.txt
# Loaded record_5300.txt
# Loaded record_5302.txt
# Loaded record_5307.txt
# Loaded record_5313.txt
# Loaded record_5314.txt
# Loaded record_5316.txt
# Loaded record_5318.txt
# Loaded record_5319.txt
# Loaded record_532.txt
# Loaded record_5324.txt
# Loaded record_5327.txt
# Loaded record_5329.txt
# Loaded record_533.txt
# Loaded record_5330.txt
# Loaded record_5331.txt
# Loaded record_5340.txt
# Loaded record_5342.txt
# Loaded record_559.txt
# Loaded record_5592.txt
# Loaded record_5593.txt
# Loaded record_5596.txt
# Loaded record_5599.txt
# Loaded record_5603.txt
# Loaded record_5604.txt
# Loaded record_5605.txt
# Loaded record_5608.txt
# Loaded record_5609.txt
# Loaded record_5610.txt
# Loaded record_5619.txt
# Loaded record_5622.txt
# Loaded record_5625.txt
# Loaded record_5628.txt
# Loaded record_5633.txt
# Loaded record_5634.txt
# Loaded record_5636.txt
# Loaded record_5638.txt
# Loaded record_564.txt
# Loaded record_5647.txt
# Loaded record_5649.txt
# Loaded record_5652.txt
# Loaded record_5654.txt
# Loaded record_5656.txt
# Loaded record_5659.txt
# Loaded record_566.txt
# Loaded record_5661.txt
# Loaded record_5662.txt
# Loaded record_5670.txt
# Loaded record_5671.txt
# Loaded record_5672.txt
# Loaded record_5674.txt
# Loaded record_5675.txt
# Loaded record_5676.txt
# Loaded record_5677.txt
# Loaded record_5678.txt
# Loaded record_5679.txt
# Loaded record_568.txt
# Loaded record_5683.txt
# Loaded record_5684.txt
# Loaded record_5686.txt
# Loaded record_5687.txt
# Loaded record_5688.txt
# Loaded record_5698.txt
# Loaded record_5699.txt
# Loaded record_57.txt
# Loaded record_5700.txt
# Loaded record_5701.txt
# Loaded record_5703.txt
# Loaded record_5706.txt
# Loaded record_5707.txt
# Loaded record_5711.txt
# Loaded record_5719.txt
# Loaded record_5721.txt
# Loaded record_5723.txt
# Loaded record_5727.txt
# Loaded record_5728.txt
# Loaded record_5729.txt
# Loaded record_5733.txt
# Loaded record_5734.txt
# Loaded record_5737.txt
# Loaded record_5738.txt
# Loaded record_5741.txt
# Loaded record_5742.txt
# Loaded record_5744.txt
# Loaded record_5746.txt
# Loaded record_5748.txt
# Loaded record_5749.txt
# Loaded record_575.txt
# Loaded record_5750.txt
# Loaded record_5754.txt
# Loaded record_5755.txt
# Loaded record_5757.txt
# Loaded record_576.txt
# Loaded record_5760.txt
# Loaded record_5765.txt
# Loaded record_5766.txt
# Loaded record_5768.txt
# Loaded record_5769.txt
# Loaded record_577.txt
# Loaded record_5770.txt
# Loaded record_5771.txt
# Loaded record_5777.txt
# Loaded record_5781.txt
# Loaded record_5784.txt
# Loaded record_5788.txt
# Loaded record_5790.txt
# Loaded record_5792.txt
# Loaded record_5795.txt
# Loaded record_5808.txt
# Loaded record_581.txt
# Loaded record_5810.txt
# Loaded record_5814.txt
# Loaded record_5815.txt
# Loaded record_5820.txt
# Loaded record_5822.txt
# Loaded record_5825.txt
# Loaded record_5829.txt
# Loaded record_583.txt
# Loaded record_5830.txt
# ...
# Loaded record_8449.txt
# Loaded record_8452.txt
# Loaded record_8455.txt
# Loaded record_8457.txt
# Loaded record_846.txt
# Loaded record_8460.txt
# Loaded record_8461.txt
# Loaded record_8463.txt
# Loaded record_8464.txt
# Loaded record_847.txt
# Loaded record_8470.txt
# Loaded record_8472.txt
# Loaded record_8475.txt
# Loaded record_8476.txt
# Loaded record_848.txt
# Loaded record_8480.txt
# Loaded record_8485.txt
# Loaded record_8487.txt
# Loaded record_8490.txt
# Loaded record_8492.txt
# Loaded record_8493.txt
# Loaded record_8495.txt
# Loaded record_8498.txt
# Loaded record_85.txt
# Loaded record_850.txt
# Loaded record_8501.txt
# Loaded record_8506.txt
# Loaded record_8507.txt
# Loaded record_8508.txt
# Loaded record_8510.txt
# Loaded record_8514.txt
# Loaded record_8517.txt
# Loaded record_8518.txt
# Loaded record_8519.txt
# Loaded record_8520.txt
# Loaded record_8521.txt
# Loaded record_8525.txt
# Loaded record_8531.txt
# Loaded record_8533.txt
# Loaded record_8535.txt
# Loaded record_8536.txt
# Loaded record_8540.txt
# Loaded record_8541.txt
# Loaded record_8544.txt
# Loaded record_8546.txt
# Loaded record_8547.txt
# Loaded record_8548.txt
# Loaded record_8553.txt
# Loaded record_8554.txt
# Loaded record_8555.txt
# Loaded record_8559.txt
# Loaded record_8561.txt
# Loaded record_8562.txt
# Loaded record_8563.txt
# Loaded record_8564.txt
# Loaded record_8565.txt
# Loaded record_857.txt
# Loaded record_8571.txt
# Loaded record_8573.txt
# Loaded record_8577.txt
# Loaded record_8579.txt
# Loaded record_8580.txt
# Loaded record_8581.txt
# Loaded record_8584.txt
# Loaded record_8589.txt
# Loaded record_8592.txt
# Loaded record_860.txt
# Loaded record_8600.txt
# Loaded record_8603.txt
# Loaded record_8604.txt
# Loaded record_8605.txt
# Loaded record_8607.txt
# Loaded record_8608.txt
# Loaded record_861.txt
# Loaded record_8610.txt
# Loaded record_8614.txt
# Loaded record_8615.txt
# Loaded record_8617.txt
# Loaded record_8619.txt
# Loaded record_8620.txt
# Loaded record_8626.txt
# Loaded record_8627.txt
# Loaded record_863.txt
# Loaded record_8630.txt
# Loaded record_8634.txt
# Loaded record_8638.txt
# Loaded record_8639.txt
# Loaded record_8642.txt
# Loaded record_8650.txt
# Loaded record_8651.txt
# Loaded record_8654.txt
# Loaded record_8657.txt
# Loaded record_8660.txt
# Loaded record_8663.txt
# Loaded record_8664.txt
# Loaded record_8666.txt
# Loaded record_8667.txt
# Loaded record_8669.txt
# Loaded record_8671.txt
# Loaded record_8675.txt
# Loaded record_8676.txt
# Loaded record_8679.txt
# Loaded record_8684.txt
# Loaded record_8686.txt
# Loaded record_8687.txt
# Loaded record_8689.txt
# Loaded record_8695.txt
# Loaded record_8697.txt
# Loaded record_87.txt
# Loaded record_8700.txt
# Loaded record_8704.txt
# Loaded record_8706.txt
# Loaded record_8707.txt
# Loaded record_8709.txt
# Loaded record_871.txt
# Loaded record_8710.txt
# Loaded record_8713.txt
# Loaded record_8714.txt
# Loaded record_8718.txt
# Loaded record_8719.txt
# Loaded record_872.txt
# Loaded record_8720.txt
# Loaded record_8726.txt
# Loaded record_8734.txt
# Loaded record_8739.txt
# Loaded record_8740.txt
# Loaded record_8747.txt
# Loaded record_8749.txt
# Loaded record_875.txt
# Loaded record_8751.txt
# Loaded record_8753.txt
# Loaded record_8754.txt
# Loaded record_8755.txt
# Loaded record_876.txt
# Loaded record_8763.txt
# Loaded record_8768.txt
# Loaded record_8769.txt
# Loaded record_8770.txt
# Loaded record_8772.txt
# Loaded record_8773.txt
# Loaded record_8776.txt
# Loaded record_8777.txt
# Loaded record_8778.txt
# Loaded record_8779.txt
# Loaded record_8786.txt
# Loaded record_8790.txt
# Loaded record_8791.txt
# Loaded record_8792.txt
# Loaded record_8793.txt
# Loaded record_8795.txt
# Loaded record_880.txt
# Loaded record_8801.txt
# Loaded record_8802.txt
# Loaded record_8805.txt
# Loaded record_8808.txt
# Loaded record_8812.txt
# Loaded record_8814.txt
# Loaded record_8815.txt
# Loaded record_8816.txt
# Loaded record_882.txt
# Loaded record_8820.txt
# Loaded record_8821.txt
# Loaded record_8822.txt
# Loaded record_8825.txt
# Loaded record_8827.txt
# Loaded record_8828.txt
# Loaded record_8829.txt
# Loaded record_8831.txt
# Loaded record_8834.txt
# Loaded record_8836.txt
# Loaded record_8837.txt
# Loaded record_8838.txt
# Loaded record_8839.txt
# Loaded record_8840.txt
# Loaded record_8844.txt
# Loaded record_8845.txt
# Loaded record_8848.txt
# Loaded record_885.txt
# Loaded record_8850.txt
# Loaded record_8852.txt
# Loaded record_8853.txt
# Loaded record_8854.txt
# Loaded record_8857.txt
# Loaded record_8858.txt
# Loaded record_8860.txt
# Loaded record_8862.txt
# Loaded record_8863.txt
# Loaded record_8864.txt
# Loaded record_8869.txt
# Loaded record_8873.txt
# Loaded record_8875.txt
# Loaded record_8877.txt
# Loaded record_8879.txt
# Loaded record_8880.txt
# Loaded record_8882.txt
# Loaded record_8883.txt
# Loaded record_8884.txt
# Loaded record_8886.txt
# Loaded record_8887.txt
# Loaded record_8889.txt
# Loaded record_889.txt
# Loaded record_8893.txt
# Loaded record_8897.txt
# Loaded record_89.txt
# Loaded record_8900.txt
# Loaded record_8902.txt
# Loaded record_8903.txt
# Loaded record_8905.txt
# Loaded record_8908.txt
# Loaded record_8909.txt
# Loaded record_891.txt
# Loaded record_8910.txt
# Loaded record_8914.txt
# Loaded record_892.txt
# Loaded record_8921.txt
# Loaded record_8925.txt
# Loaded record_8926.txt
# Loaded record_8928.txt
# Loaded record_8930.txt
# Loaded record_8931.txt
# Loaded record_8932.txt
# Loaded record_8933.txt
# Loaded record_8934.txt
# Loaded record_8939.txt
# Loaded record_8940.txt
# Loaded record_8944.txt
# Loaded record_8945.txt
# Loaded record_8947.txt
# Loaded record_8948.txt
# Loaded record_8949.txt
# Loaded record_895.txt
# Loaded record_8951.txt
# Loaded record_8954.txt
# Loaded record_8955.txt
# Loaded record_8957.txt
# Loaded record_8958.txt
# Loaded record_8960.txt
# Loaded record_8961.txt
# Loaded record_8964.txt
# Loaded record_8966.txt
# Loaded record_8967.txt
# Loaded record_8975.txt
# Loaded record_8976.txt
# Loaded record_8977.txt
# Loaded record_898.txt
# Loaded record_8984.txt
# Loaded record_8985.txt
# Loaded record_8988.txt
# Loaded record_8989.txt
# Loaded record_8993.txt
# Loaded record_8996.txt
# Loaded record_8999.txt
# Loaded record_9.txt
# Loaded record_9000.txt
# Loaded record_9001.txt
# Loaded record_9545.txt
# Loaded record_9547.txt
# Loaded record_955.txt
# Loaded record_9550.txt
# Loaded record_9551.txt
# Loaded record_9552.txt
# Loaded record_9559.txt
# Loaded record_956.txt
# Loaded record_9561.txt
# Loaded record_9566.txt
# Loaded record_9567.txt
# Loaded record_9569.txt
# Loaded record_9576.txt
# Loaded record_9581.txt
# Loaded record_9582.txt
# Loaded record_9585.txt
# Loaded record_9587.txt
# Loaded record_9589.txt
# Loaded record_9593.txt
# Loaded record_9596.txt
# Loaded record_9600.txt
# Loaded record_9602.txt
# Loaded record_9603.txt
# Loaded record_9604.txt
# Loaded record_9605.txt
# Loaded record_9608.txt
# Loaded record_9609.txt
# Loaded record_9610.txt
# Loaded record_9612.txt
# Loaded record_9614.txt
# Loaded record_9615.txt
# Loaded record_9617.txt
# Loaded record_9619.txt
# Loaded record_9625.txt
# Loaded record_9630.txt
# Loaded record_9636.txt
# Loaded record_9640.txt
# Loaded record_9642.txt
# Loaded record_9644.txt
# Loaded record_9645.txt
# Loaded record_9646.txt
# Loaded record_9648.txt
# Loaded record_9649.txt
# Loaded record_9651.txt
# Loaded record_9654.txt
# Loaded record_9655.txt
# Loaded record_9661.txt
# Loaded record_9663.txt
# Loaded record_9664.txt
# Loaded record_9668.txt
# Loaded record_9669.txt
# Loaded record_967.txt
# Loaded record_9670.txt
# Loaded record_9671.txt
# Loaded record_9675.txt
# Loaded record_9676.txt
# Loaded record_9678.txt
# Loaded record_968.txt
# Loaded record_9682.txt
# Loaded record_9683.txt
# Loaded record_9686.txt
# Loaded record_9687.txt
# Loaded record_9688.txt
# Loaded record_969.txt
# Loaded record_9692.txt
# Loaded record_9695.txt
# Loaded record_9696.txt
# Loaded record_9698.txt
# Loaded record_9700.txt
# Loaded record_9702.txt
# Loaded record_9708.txt
# Loaded record_9715.txt
# Loaded record_9716.txt
# Loaded record_9717.txt
# Loaded record_9719.txt
# Loaded record_972.txt
# Loaded record_9722.txt
# Loaded record_9723.txt
# Loaded record_9725.txt
# Loaded record_9726.txt
# Loaded record_9728.txt
# Loaded record_9729.txt
# Loaded record_9731.txt
# Loaded record_9733.txt
# Loaded record_9737.txt
# Loaded record_9739.txt
# Loaded record_9740.txt
# Loaded record_9744.txt
# Loaded record_9745.txt
# Loaded record_9748.txt
# Loaded record_9752.txt
# Loaded record_9754.txt
# Loaded record_9755.txt
# Loaded record_9756.txt
# Loaded record_9757.txt
# Loaded record_9759.txt
# Loaded record_9760.txt
# Loaded record_9761.txt
# Loaded record_9763.txt
# Loaded record_9766.txt
# Loaded record_9768.txt
# Loaded record_9772.txt
# Loaded record_9773.txt
# Loaded record_9774.txt
# Loaded record_9775.txt
# Loaded record_9779.txt
# Loaded record_9782.txt
# Loaded record_9785.txt
# Loaded record_9786.txt
# Loaded record_9787.txt
# Loaded record_9788.txt
# Loaded record_9792.txt
# Loaded record_9794.txt
# Loaded record_9799.txt
# Loaded record_98.txt
# Loaded record_9800.txt
# Loaded record_9802.txt
# Loaded record_9804.txt
# Loaded record_9810.txt
# Loaded record_9812.txt
# Loaded record_9818.txt
# Loaded record_9819.txt
# Loaded record_9821.txt
# Loaded record_9822.txt
# Loaded record_9823.txt
# Loaded record_9825.txt
# Loaded record_9831.txt
# Loaded record_9833.txt
# Loaded record_9834.txt
# Loaded record_9835.txt
# Loaded record_9836.txt
# Loaded record_9838.txt
# Loaded record_984.txt
# Loaded record_9840.txt
# Loaded record_9841.txt
# Loaded record_9843.txt
# Loaded record_9846.txt
# Loaded record_9849.txt
# Loaded record_9850.txt
# Loaded record_9853.txt
# Loaded record_9856.txt
# Loaded record_9857.txt
# Loaded record_9858.txt
# Loaded record_9860.txt
# Loaded record_9863.txt
# Loaded record_9865.txt
# Loaded record_987.txt
# Loaded record_9870.txt
# Loaded record_9875.txt
# Loaded record_9877.txt
# Loaded record_9878.txt
# Loaded record_9880.txt
# Loaded record_9883.txt
# Loaded record_9888.txt
# Loaded record_9889.txt
# Loaded record_9890.txt
# Loaded record_9891.txt
# Loaded record_9896.txt
# Loaded record_9898.txt
# Loaded record_990.txt
# Loaded record_9900.txt
# Loaded record_9901.txt
# Loaded record_9902.txt
# Loaded record_9903.txt
# Loaded record_9914.txt
# Loaded record_9916.txt
# Loaded record_9917.txt
# Loaded record_9922.txt
# Loaded record_9924.txt
# Loaded record_9925.txt
# Loaded record_9928.txt
# Loaded record_9929.txt
# Loaded record_993.txt
# Loaded record_9930.txt
# Loaded record_9931.txt
# Loaded record_9933.txt
# Loaded record_9934.txt
# Loaded record_9935.txt
# Loaded record_9936.txt
# Loaded record_9939.txt
# Loaded record_994.txt
# Loaded record_9940.txt
# Loaded record_9942.txt
# Loaded record_9945.txt
# Loaded record_9946.txt
# Loaded record_9949.txt
# Loaded record_995.txt
# Loaded record_9951.txt
# Loaded record_9957.txt
# Loaded record_9958.txt
# Loaded record_9960.txt
# Loaded record_9963.txt
# Loaded record_9968.txt
# Loaded record_997.txt
# Loaded record_9970.txt
# Loaded record_9971.txt
# Loaded record_9973.txt
# Loaded record_9975.txt
# Loaded record_9978.txt
# Loaded record_9980.txt
# Loaded record_9984.txt
# Loaded record_9987.txt
# Loaded record_999.txt
# Loaded record_9990.txt
# Loaded record_9998.txt
# Loaded record_9999.txt

# %% [markdown]
# #### Clean Text Data

# %%
from nltk.corpus import stopwords
import string
import re

# load doc into memory
def load_doc(filename):
    # open the file as read only
    file = open(filename, 'r', encoding="utf-8")
    # read all text
    text = file.read()
    # close the file
    file.close()
    return text
# turn a doc into clean tokens
def clean_doc(doc):
    # split into tokens by white space
    tokens = doc.split()
    # prepare regex for char filtering
    re_punc = re.compile('[%s]' % re.escape(string.punctuation))
    # remove punctuation from each word
    tokens = [re_punc.sub('', w) for w in tokens]
    # remove remaining tokens that are not alphabetic
    tokens = [word for word in tokens if word.isalpha()]
    # filter out stop words
    stop_words = set(stopwords.words('english'))
    tokens = [w for w in tokens if not w in stop_words]
    # filter out short tokens
    tokens = [word for word in tokens if len(word) > 1]
    return tokens
# load the document
filename = r"D:\NLP\Deep_Learning_in_NLP\phishing_detection\Clean\record_11.txt"
text = load_doc(filename)
tokens = clean_doc(text)
print(tokens)
# Out:
# ['URL', 'Date', 'httpwwwnewsisfreecomImagesfarkcbccagif', 'CBC']

# %% [markdown]
# ##### Develop Vocabulary

# %%
import string
import re
from os import listdir
from collections import Counter
from nltk.corpus import stopwords

# load doc into memory
def load_doc(filename):
    # open the file as read only
    file = open(filename, 'r', encoding="utf-8")
    # read all text
    text = file.read()
    # close the file
    file.close()
    return text


# turn a doc into clean tokens
def clean_doc(doc):
    # split into tokens by white space
    tokens = doc.split()
    # prepare regex for char filtering
    re_punc = re.compile('[%s]' % re.escape(string.punctuation))
    # remove punctuation from each word
    tokens = [re_punc.sub('', w) for w in tokens]
    # remove remaining tokens that are not alphabetic
    tokens = [word for word in tokens if word.isalpha()]
    # filter out stop words
    stop_words = set(stopwords.words('english'))
    tokens = [w for w in tokens if not w in stop_words]
    # filter out short tokens
    tokens = [word for word in tokens if len(word) > 1]
    return tokens


# load doc and add to vocab
def add_doc_to_vocab(filename, vocab):
# load doc
    doc = load_doc(filename)
    # clean doc
    tokens = clean_doc(doc)
    # update counts
    vocab.update(tokens)


# load all docs in a directory
def process_docs(directory, vocab):
    # walk through all files in the folder
    for filename in listdir(directory):
        # skip files that do not have the right extension
        if not filename.endswith(".txt"):
            next
        # create the full path of the file to open
        path = directory + '/' + filename
        # add doc to vocab
        add_doc_to_vocab(path, vocab)

# save list to file
def save_list(lines, filename):
    data = '\n'.join(lines)
    file = open(filename, 'w')
    file.write(data)
    file.close()


# define vocab
vocab = Counter()
# add all docs to vocab
process_docs(r"D:\NLP\Deep_Learning_in_NLP\phishing_detection\Clean", vocab)
process_docs(r"D:\NLP\Deep_Learning_in_NLP\phishing_detection\Phishing", vocab)
# print the size of the vocab
print(len(vocab))
# print the top words in the vocab
print(vocab.most_common(50))
# keep tokens with > 5 occurrence
min_occurane = 5
tokens = [k for k,c in vocab.items() if c >= min_occurane]
print(len(tokens))
# save tokens to a vocabulary file
save_list(tokens, 'vocab.txt')
# Out:
# 103467
# [('enron', 6686), ('email', 4281), ('please', 3767), ('one', 3721), ('information', 3695), ('company', 3620), ('ect', 3490), ('would', 3396), ('new', 3379), ('com', 3361), ('get', 2990), ('time', 2955), ('may', 2816), ('us', 2557), ('business', 2500), ('like', 2470), ('also', 2369), ('http', 2287), ('list', 2281), ('mail', 2182), ('make', 2087), ('language', 2079), ('people', 2071), ('subject', 2067), ('use', 2044), ('The', 2017), ('de', 1979), ('know', 1964), ('money', 1962), ('university', 1955), ('said', 1945), ('message', 1896), ('address', 1891), ('free', 1857), ('hou', 1819), ('need', 1807), ('work', 1691), ('send', 1670), ('see', 1664), ('could', 1641), ('order', 1640), ('report', 1627), ('www', 1621), ('first', 1602), ('price', 1500), ('want', 1485), ('program', 1443), ('two', 1427), ('name', 1419), ('within', 1410)]
# 22261

# %% [markdown]
# ##### Save Prepared Data

# %%
import string
import re
from os import listdir
from nltk.corpus import stopwords

# load doc into memory
def load_doc(filename):
    # open the file as read only
    file = open(filename, 'r', encoding="latin-1")
    # read all text
    text = file.read()
    # close the file
    file.close()
    return text

# turn a doc into clean tokens
def clean_doc(doc):
    # split into tokens by white space
    tokens = doc.split()
    # prepare regex for char filtering
    re_punc = re.compile('[%s]' % re.escape(string.punctuation))
    # remove punctuation from each word
    tokens = [re_punc.sub('', w) for w in tokens]
    # remove remaining tokens that are not alphabetic
    tokens = [word for word in tokens if word.isalpha()]
    # filter out stop words
    stop_words = set(stopwords.words('english'))
    tokens = [w for w in tokens if not w in stop_words]
    # filter out short tokens
    tokens = [word for word in tokens if len(word) > 1]
    return tokens

# save list to file
def save_list(lines, filename):
    data = '\n'.join(lines)
    file = open(filename, 'w')
    file.write(data)
    file.close()

# load doc, clean and return line of tokens
def doc_to_line(filename, vocab):
    # load the doc
    doc = load_doc(filename)
    # clean doc
    tokens = clean_doc(doc)
    # filter by vocab
    tokens = [w for w in tokens if w in vocab]
    return ' '.join(tokens)

# load all docs in a directory
def process_docs(directory, vocab):
    lines = list()
    # walk through all files in the folder
    for filename in listdir(directory):
        # skip files that do not have the right extension
        if not filename.endswith(".txt"):
            next
    # create the full path of the file to open
        path = directory + '/' + filename
        # load and clean the doc
        line = doc_to_line(path, vocab)
        # add to list
        lines.append(line)
    return lines

# load vocabulary
vocab_filename = 'vocab.txt'
vocab = load_doc(vocab_filename)
vocab = vocab.split()
vocab = set(vocab)
# prepare negative reviews
negative_lines = process_docs(r"D:\NLP\Deep_Learning_in_NLP\phishing_detection\Phishing", vocab)
save_list(negative_lines, 'negative.txt')
# prepare positive reviews
positive_lines = process_docs(r"D:\NLP\Deep_Learning_in_NLP\phishing_detection\Clean", vocab)
save_list(positive_lines, 'positive.txt')
